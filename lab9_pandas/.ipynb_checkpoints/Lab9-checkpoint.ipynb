# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read and clean data

# %%
# df_plant1 = pd.read_csv('Plant_1_Generation_Data.csv', index_col=[1,2,0], parse_dates=True)
# df_plant2 = pd.read_csv('Plant_2_Generation_Data.csv', index_col=[1,2,0], parse_dates=True)
df_plant1 = pd.read_csv('Plant_1_Generation_Data.csv')
df_plant2 = pd.read_csv('Plant_2_Generation_Data.csv')

# %%
df_plant1.head()
# Out:
#           DATE_TIME   PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00  4135001.0  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00  4135001.0  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00  4135001.0  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00  4135001.0  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
df_plant2.head()
# Out:
#              DATE_TIME   PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  2020-05-15 00:00:00  4136001.0  4UPUqMRk7TRMgml       0.0       0.0
# 1  2020-05-15 00:00:00  4136001.0  81aHJ1q11NBPMrL       0.0       0.0
# 2  2020-05-15 00:00:00  4136001.0  9kRcWv60rDACzjR       0.0       0.0
# 3  2020-05-15 00:00:00  4136001.0  Et9kgGMDl729KT4       0.0       0.0
# 4  2020-05-15 00:00:00  4136001.0  IQ2d7wF4YD8zU1Q       0.0       0.0
#
#    DAILY_YIELD   TOTAL_YIELD
# 0  9425.000000  2.429011e+06
# 1     0.000000  1.215279e+09
# 2  3075.333333  2.247720e+09
# 3   269.933333  1.704250e+06
# 4  3177.000000  1.994153e+07

# %%
df = pd.concat([df_plant1, df_plant2])

# %%
df.isna().sum()
# Out:
# DATE_TIME      0
# PLANT_ID       2
# SOURCE_KEY     0
# DC_POWER       1
# AC_POWER       1
# DAILY_YIELD    1
# TOTAL_YIELD    2
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# DATE_TIME      0
# PLANT_ID       0
# SOURCE_KEY     0
# DC_POWER       0
# AC_POWER       0
# DAILY_YIELD    0
# TOTAL_YIELD    0
# dtype: int64

# %%
df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])

# %%
df = df.set_index(['PLANT_ID', 'SOURCE_KEY', 'DATE_TIME']) # czy PLANT_ID jest tutaj potrzebne?

# %%
df.head()
# Out:
#                                       DC_POWER  AC_POWER  DAILY_YIELD  \
# PLANT_ID  SOURCE_KEY      DATE_TIME
# 4135001.0 1BY6WEcLGh8j5v7 2020-05-15       0.0       0.0          0.0
#           1IF53ai7Xc0U56Y 2020-05-15       0.0       0.0          0.0
#           3PZuoBAID5Wc2HD 2020-05-15       0.0       0.0          0.0
#           7JYdWkrLSPkdwr4 2020-05-15       0.0       0.0          0.0
#           McdE0feGgRqW7Ca 2020-05-15       0.0       0.0          0.0
#
#                                       TOTAL_YIELD
# PLANT_ID  SOURCE_KEY      DATE_TIME
# 4135001.0 1BY6WEcLGh8j5v7 2020-05-15    6259559.0
#           1IF53ai7Xc0U56Y 2020-05-15    6183645.0
#           3PZuoBAID5Wc2HD 2020-05-15    6987759.0
#           7JYdWkrLSPkdwr4 2020-05-15    7602960.0
#           McdE0feGgRqW7Ca 2020-05-15    7158964.0

# %% [markdown]
# # Plots

# %% [markdown]
# ### Plot of choosen week

# %%
plt.figure(figsize=(15,5))
plt.plot(df.loc[4135001.0, '1BY6WEcLGh8j5v7']['AC_POWER']['2020-05-15 00:00:00':'2020-05-22 00:00:00'],
         'o', label='AC_POWER for 1BY6WEcLGh8j5v7')
plt.plot(df.loc[4135001.0].groupby(level=1).mean()['AC_POWER']['2020-05-15 00:00:00':'2020-05-22 00:00:00'],
         '.',alpha=0.5,  label='Mean AC_POWER for plant 1')
plt.plot(df.groupby(level=2).mean()['AC_POWER']['2020-05-15 00:00:00':'2020-05-22 00:00:00'],
         '.',alpha=0.2, label='Mean AC_POWER for both plants')
plt.legend()
plt.show()
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.

# %% [markdown]
# ### Plot of the whole date range

# %%
plt.figure(figsize=(15,5))
plt.plot(df.loc[4135001.0, '1BY6WEcLGh8j5v7']['AC_POWER'], 'o', label='AC_POWER for 1BY6WEcLGh8j5v7')
plt.plot(df.loc[4135001.0].groupby(level=1).mean()['AC_POWER'], '.',alpha=0.5,  label='Mean AC_POWER for plant 1')
plt.plot(df.groupby(level=2).mean()['AC_POWER'], '.',alpha=0.2, label='Mean AC_POWER for both plants')
plt.legend()
plt.show()
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.

# %% [markdown]
# # Searching for low-performance generators

# %%
def get_low_perfomances(df, plant_id):
    df_temp = df.loc[plant_id]
    mean_plant = pd.DataFrame(df_temp.groupby(level=1).mean()['AC_POWER'])
    idxs = df_temp.index.get_level_values('DATE_TIME')
    df_temp['mean'] = mean_plant.loc[idxs].values
    lower_performances = df_temp[['AC_POWER', 'mean']][df_temp['AC_POWER'] < 0.8 * df_temp['mean'] ]
    del df_temp
    return lower_performances

# %% [markdown]
# ### Plant 1

# %%
lower_performances1 = get_low_perfomances(df, 4135001.0)

# %% [markdown]
# dataframe with all requested situations

# %%
lower_performances1.head()
# Out:
#                                        AC_POWER        mean
# SOURCE_KEY      DATE_TIME
# VHMLBKoKgIrUVDU 2020-05-15 06:00:00    0.000000    4.329960
# ZoEaEvLYb1n2sOq 2020-05-15 06:00:00    2.366667    4.329960
# zVJPv84UY57bAof 2020-05-15 06:00:00    3.362500    4.329960
# VHMLBKoKgIrUVDU 2020-05-15 06:15:00    5.912500   28.254223
# zVJPv84UY57bAof 2020-05-15 08:45:00  292.437500  412.730357

# %% [markdown]
# worst generators

# %%
lower_performances1['AC_POWER'].groupby(level=0).count().sort_values(ascending=False)
# Out:
# SOURCE_KEY
# bvBOhCH3iADSZry    82
# 1BY6WEcLGh8j5v7    77
# z9Y9gH1T5YWrNuG    38
# WRmjgnKYAwPKWDb    33
# zVJPv84UY57bAof    31
# pkci93gMrogZuBj    29
# uHbuxQJl8lW7ozc    26
# zBIq5rxdHJRwDNY    26
# rGa61gmuvPhdLxV    26
# wCURE6d3bPkepu2    21
# sjndEbLyjtCKgGv    20
# ih0vzX44oOqAx2f    19
# iCRJl6heRkivqQ3    19
# McdE0feGgRqW7Ca    18
# 3PZuoBAID5Wc2HD    18
# YxYtjZvoooNbGkE    15
# VHMLBKoKgIrUVDU    14
# 7JYdWkrLSPkdwr4    14
# ZoEaEvLYb1n2sOq    12
# 1IF53ai7Xc0U56Y    11
# ZnxXDlPa8U1GXgE    10
# adLQvlD726eNBSB     4
# Name: AC_POWER, dtype: int64

# %% [markdown]
# ### Plant 2

# %%
lower_performances2 = get_low_perfomances(df, 4136001.0)

# %% [markdown]
# dataframe with all requested situations

# %%
lower_performances2.head()
# Out:
#                                        AC_POWER        mean
# SOURCE_KEY      DATE_TIME
# Quc1TzYxW2pYoWX 2020-05-15 06:00:00   11.013333   14.565152
#                 2020-05-15 06:15:00   20.278571   25.771710
#                 2020-05-15 06:30:00   43.086667   56.525281
#                 2020-05-15 06:45:00  118.626667  153.348117
# 81aHJ1q11NBPMrL 2020-05-15 09:30:00  549.246667  888.762165

# %% [markdown]
# worst generators

# %%
lower_performances2['AC_POWER'].groupby(level=0).count().sort_values(ascending=False)
# Out:
# SOURCE_KEY
# Quc1TzYxW2pYoWX    555
# Et9kgGMDl729KT4    370
# LYwnQax7tkwH5Cb    360
# rrq4fwE8jgrTyWY    325
# WcxssY2VbP4hApt    325
# 81aHJ1q11NBPMrL    302
# q49J1IKaHRwDQnt    287
# xoJJ8DcxJEcupym    240
# 9kRcWv60rDACzjR    222
# LlT2YUhhzqhg5Sw    219
# PeE6FRyGXUgsRhN    216
# oZZkBaNadn6DNKz    210
# V94E5Ben1TlhnDV    197
# vOuJvMaM2sgwLmb    178
# oZ35aAeoifZaQzV    158
# 4UPUqMRk7TRMgml    153
# Qf4GUc1pJu5T6c6    152
# Mx2yZCDsyf6DPfv    124
# NgDl19wMapZy17u     44
# mqwcsP2rE7J0TFp     33
# IQ2d7wF4YD8zU1Q     24
# xMbIugepa2P7lBB     23
# Name: AC_POWER, dtype: int64
